# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('GBMdata_cBioPortal.csv')
print(df.head(3))
# Out:
#               Patient ID  Age at PD-1 Therapy  \
# 0  gbm_columbia_2019_100                 31.0
# 1  gbm_columbia_2019_101                 32.0
# 2  gbm_columbia_2019_102                 64.0
#
#   Best Response to PD1 Inhibitor (RANO) Bev Failure Before PD1 Inhibitor  \
# 0                                    SD                               No
# 1                                   NaN                               No
# 2                                   NaN                               No
#
#       Cancer Type Detailed  \
# 0  Glioblastoma Multiforme
# 1  Glioblastoma Multiforme
# 2  Glioblastoma Multiforme
#
#    Drug Dose (mg/day) (Steroids During PD1 Inhibitor)  \
# 0                                                2.0
# 1                                                5.0
# 2                                               10.0
#
#    Drug Dose (mg/day) (Steroids When Started PD1 Inhibitor)   \
# 0                                                2.0
# ...

# %%
print (df[['Patient ID', 'Progress Free Survival (Months)']])
# Out:
#                 Patient ID  Progress Free Survival (Months)
# 0    gbm_columbia_2019_100                        51.764384
# 1    gbm_columbia_2019_101                              NaN
# 2    gbm_columbia_2019_102                        41.063014
# 3    gbm_columbia_2019_103                        26.169863
# 4    gbm_columbia_2019_104                        55.015068
# ..                     ...                              ...
# 835           TCGA-87-5896                        26.301082
# 836           TCGA-OX-A56R                         5.917743
# 837           TCGA-RR-A6KA                         6.279383
# 838           TCGA-RR-A6KB                         0.000000
# 839           TCGA-RR-A6KC                        12.131374
#
# [840 rows x 2 columns]

# %%
df.describe()
# Out:
#        Age at PD-1 Therapy  \
# count            42.000000
# mean             51.285714
# std              14.732221
# min              24.000000
# 25%              38.250000
# 50%              54.000000
# 75%              63.750000
# max              73.000000
#
#        Drug Dose (mg/day) (Steroids During PD1 Inhibitor)  \
# count                                          31.000000
# mean                                            5.483871
# std                                            11.171753
# min                                             0.500000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                            60.000000
#
#        Drug Dose (mg/day) (Steroids When Started PD1 Inhibitor)   \
# count                                          22.000000
# mean                                            2.477273
# ...

# %%
df.loc[df['PD1 Inhibitor With Imatinib'] == "Yes"]
# Out:
#               Patient ID  Age at PD-1 Therapy  \
# 1  gbm_columbia_2019_101                 32.0
#
#   Best Response to PD1 Inhibitor (RANO) Bev Failure Before PD1 Inhibitor  \
# 1                                   NaN                               No
#
#       Cancer Type Detailed  \
# 1  Glioblastoma Multiforme
#
#    Drug Dose (mg/day) (Steroids During PD1 Inhibitor)  \
# 1                                                5.0
#
#    Drug Dose (mg/day) (Steroids When Started PD1 Inhibitor)   \
# 1                                                NaN
#
#   Dose Of Pembrolizumab Per Injection (mg/kg) Dose Of Re-irradiation  \
# 1                                         NaN    35 Gy, 10 fractions
#
#   Drug Name (Steroids During PD1 Inhibitor)   ... PD1 Inhibitor With Imatinib  \
# 1                                        dex  ...                         Yes
#
#   Progress Free Survival (Months)  Progression Free Status Rash  Response  \
# ...

# %%
print (df.columns)
# Out:
# Index(['Patient ID', 'Age at PD-1 Therapy',
#        'Best Response to PD1 Inhibitor (RANO)',
#        'Bev Failure Before PD1 Inhibitor', 'Cancer Type Detailed',
#        'Drug Dose (mg/day) (Steroids During PD1 Inhibitor)',
#        'Drug Dose (mg/day) (Steroids When Started PD1 Inhibitor) ',
#        'Dose Of Pembrolizumab Per Injection (mg/kg)', 'Dose Of Re-irradiation',
#        'Drug Name (Steroids During PD1 Inhibitor) ', 'Endocrine Toxicities',
#        'Extent of Resection', 'First Recurrence', 'KPS',
#        'KPS at PD1 Inhibitor Start', 'Liver Disfunction', 'Mutation Count',
#        'Number Of PD1 Inhibitor Injections', 'Number Of Prior Recurrences',
#        'Overall Survival from PD1i (Months)',
#        'Overall Survival From PD1i  Status', 'Overall Survival (Months)',
#        'Overall Survival Status', 'PD1 Inhibitor',
#        'PD1 Inhibitor Concurrently With BCNU/CCNU',
#        'PD1 Inhibitor Concurrently With Bev',
# ...
